# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
#Get the nearest city using the citipy module.
cities[:20]
# Out:
# ['lorengau',
#  'mataura',
#  'kuche',
#  'saint-pierre',
#  'saldanha',
#  'sentyabrskiy',
#  'dikson',
#  'tuktoyaktuk',
#  'punta arenas',
#  'vaitupu',
#  'mirnyy',
#  'illoqqortoormiut',
#  'arraial do cabo',
#  'saint-philippe',
#  'bambous virieux',
#  'wasilla',
#  'victoria',
#  'rikitea',
#  'pisco',
#  'saint pete beach']

# %%
#Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fab91ea21c030c21341998e0ff6c4c4a

# %%
#Retrieve the following information from the API call:
#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lorengau
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 1 | saint-pierre
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | mirnyy
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | wasilla
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | pisco
# Processing Record 20 of Set 1 | saint pete beach
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | araouane
# Processing Record 25 of Set 1 | aldan
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | nanakuli
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | bonthe
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | minden
# Processing Record 43 of Set 1 | novyy urengoy
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | mayo
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | den chai
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | vestmannaeyjar
# Processing Record 6 of Set 2 | senanga
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | henties bay
# Processing Record 12 of Set 2 | bobo dioulasso
# Processing Record 13 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 2 | te anau
# Processing Record 15 of Set 2 | san roque
# Processing Record 16 of Set 2 | mehamn
# Processing Record 17 of Set 2 | pirovskoye
# Processing Record 18 of Set 2 | rosetta
# Processing Record 19 of Set 2 | harper
# Processing Record 20 of Set 2 | tanete
# Processing Record 21 of Set 2 | kalmunai
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | berlevag
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | beringovskiy
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | thanh hoa
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | katra
# Processing Record 31 of Set 2 | mezen
# Processing Record 32 of Set 2 | yaan
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | natal
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | shubarkuduk
# Processing Record 38 of Set 2 | san policarpo
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | mount isa
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | karratha
# Processing Record 44 of Set 2 | atar
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | amahai
# Processing Record 47 of Set 2 | bjorkelangen
# Processing Record 48 of Set 2 | malazgirt
# Processing Record 49 of Set 2 | labuan
# Processing Record 50 of Set 2 | bafut
# Processing Record 1 of Set 3 | sabha
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | ostersund
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | sepolno krajenskie
# Processing Record 6 of Set 3 | koumac
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | faanui
# Processing Record 11 of Set 3 | gelemso
# Processing Record 12 of Set 3 | praia
# Processing Record 13 of Set 3 | puerto colombia
# Processing Record 14 of Set 3 | sisimiut
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | holme
# Processing Record 17 of Set 3 | becov
# Processing Record 18 of Set 3 | khani
# Processing Record 19 of Set 3 | dajal
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 3 | high level
# Processing Record 23 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | la asuncion
# Processing Record 29 of Set 3 | machico
# Processing Record 30 of Set 3 | ambulu
# Processing Record 31 of Set 3 | agadir
# Processing Record 32 of Set 3 | aksehir
# Processing Record 33 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 34 of Set 3 | noumea
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | okulovka
# Processing Record 37 of Set 3 | zyryanka
# Processing Record 38 of Set 3 | srednekolymsk
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | ulladulla
# Processing Record 42 of Set 3 | luganville
# Processing Record 43 of Set 3 | hudiksvall
# Processing Record 44 of Set 3 | strezhevoy
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | dingle
# Processing Record 48 of Set 3 | buta
# Processing Record 49 of Set 3 | sambava
# Processing Record 50 of Set 3 | khorramshahr
# Processing Record 1 of Set 4 | buraydah
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | palora
# Processing Record 4 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 4 | butaritari
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | canete
# Processing Record 9 of Set 4 | oussouye
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 4 | suntar
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | aranos
# Processing Record 15 of Set 4 | la paz
# Processing Record 16 of Set 4 | mokhsogollokh
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | saint anthony
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | makung
# City not found. Skipping...
# Processing Record 21 of Set 4 | matadi
# Processing Record 22 of Set 4 | birjand
# Processing Record 23 of Set 4 | kruisfontein
# Processing Record 24 of Set 4 | klaksvik
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | cockburn town
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | tuy hoa
# Processing Record 31 of Set 4 | zatoka
# Processing Record 32 of Set 4 | gamba
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | cap-aux-meules
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | edson
# Processing Record 37 of Set 4 | heihe
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | kibondo
# Processing Record 41 of Set 4 | teshie
# Processing Record 42 of Set 4 | eregli
# Processing Record 43 of Set 4 | coevorden
# Processing Record 44 of Set 4 | nome
# Processing Record 45 of Set 4 | kieta
# Processing Record 46 of Set 4 | ingraj bazar
# Processing Record 47 of Set 4 | portland
# Processing Record 48 of Set 4 | along
# Processing Record 49 of Set 4 | maragogi
# Processing Record 50 of Set 4 | lasa
# Processing Record 1 of Set 5 | acarau
# Processing Record 2 of Set 5 | urucara
# Processing Record 3 of Set 5 | kyshtovka
# Processing Record 4 of Set 5 | mazamari
# Processing Record 5 of Set 5 | galveston
# Processing Record 6 of Set 5 | upernavik
# Processing Record 7 of Set 5 | ormara
# Processing Record 8 of Set 5 | eau claire
# Processing Record 9 of Set 5 | westport
# Processing Record 10 of Set 5 | puerto escondido
# Processing Record 11 of Set 5 | morant bay
# Processing Record 12 of Set 5 | dangara
# Processing Record 13 of Set 5 | pemberton
# Processing Record 14 of Set 5 | quelimane
# Processing Record 15 of Set 5 | tianpeng
# Processing Record 16 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 5 | palmer
# Processing Record 18 of Set 5 | auki
# Processing Record 19 of Set 5 | madiun
# Processing Record 20 of Set 5 | bilibino
# Processing Record 21 of Set 5 | umea
# Processing Record 22 of Set 5 | ayan
# Processing Record 23 of Set 5 | oktyabrskoye
# Processing Record 24 of Set 5 | kindu
# Processing Record 25 of Set 5 | coaticook
# Processing Record 26 of Set 5 | joshimath
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | dedougou
# Processing Record 29 of Set 5 | paulo afonso
# Processing Record 30 of Set 5 | isoka
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | marche-en-famenne
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | katobu
# Processing Record 36 of Set 5 | saint-leu
# Processing Record 37 of Set 5 | svetlogorsk
# Processing Record 38 of Set 5 | sur
# Processing Record 39 of Set 5 | makakilo city
# Processing Record 40 of Set 5 | gabu
# Processing Record 41 of Set 5 | benghazi
# Processing Record 42 of Set 5 | saint-francois
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | kargil
# Processing Record 45 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | dabwali
# Processing Record 47 of Set 5 | bumba
# Processing Record 48 of Set 5 | birakan
# Processing Record 49 of Set 5 | waddan
# Processing Record 50 of Set 5 | faya
# Processing Record 1 of Set 6 | waitati
# Processing Record 2 of Set 6 | sibolga
# Processing Record 3 of Set 6 | adrar
# Processing Record 4 of Set 6 | brae
# Processing Record 5 of Set 6 | chaozhou
# Processing Record 6 of Set 6 | homer
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | uyuni
# Processing Record 9 of Set 6 | hami
# Processing Record 10 of Set 6 | kendari
# Processing Record 11 of Set 6 | sistranda
# Processing Record 12 of Set 6 | le port
# Processing Record 13 of Set 6 | namtsy
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | dobson
# Processing Record 16 of Set 6 | vanavara
# Processing Record 17 of Set 6 | acapulco
# Processing Record 18 of Set 6 | stantsionno-oyashinskiy
# Processing Record 19 of Set 6 | ahuimanu
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 6 | kiama
# Processing Record 23 of Set 6 | cabinda
# Processing Record 24 of Set 6 | claremore
# Processing Record 25 of Set 6 | porto santo
# Processing Record 26 of Set 6 | flin flon
# Processing Record 27 of Set 6 | marystown
# Processing Record 28 of Set 6 | bongandanga
# Processing Record 29 of Set 6 | camacha
# Processing Record 30 of Set 6 | kalulushi
# Processing Record 31 of Set 6 | vila
# Processing Record 32 of Set 6 | isla vista
# Processing Record 33 of Set 6 | kildare
# Processing Record 34 of Set 6 | san patricio
# Processing Record 35 of Set 6 | skagen
# Processing Record 36 of Set 6 | nizwa
# Processing Record 37 of Set 6 | omsukchan
# Processing Record 38 of Set 6 | terra santa
# Processing Record 39 of Set 6 | cidreira
# Processing Record 40 of Set 6 | carnarvon
# Processing Record 41 of Set 6 | patan
# Processing Record 42 of Set 6 | carutapera
# Processing Record 43 of Set 6 | constitucion
# Processing Record 44 of Set 6 | zhuanghe
# Processing Record 45 of Set 6 | brokopondo
# Processing Record 46 of Set 6 | kedrovyy
# Processing Record 47 of Set 6 | capaci
# Processing Record 48 of Set 6 | zaysan
# Processing Record 49 of Set 6 | gushikawa
# Processing Record 50 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 7 | yelniki
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | los llanos de aridane
# Processing Record 4 of Set 7 | chuy
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | markova
# Processing Record 7 of Set 7 | san francisco
# Processing Record 8 of Set 7 | hay river
# Processing Record 9 of Set 7 | maumere
# Processing Record 10 of Set 7 | dunedin
# Processing Record 11 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 7 | cimarron hills
# Processing Record 13 of Set 7 | wanaka
# Processing Record 14 of Set 7 | padre bernardo
# Processing Record 15 of Set 7 | hirara
# Processing Record 16 of Set 7 | yar-sale
# Processing Record 17 of Set 7 | lazaro cardenas
# Processing Record 18 of Set 7 | babstovo
# Processing Record 19 of Set 7 | pizarro
# Processing Record 20 of Set 7 | mettur
# Processing Record 21 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 7 | ust-ordynskiy
# Processing Record 23 of Set 7 | uthal
# Processing Record 24 of Set 7 | rio grande
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | miraflores
# Processing Record 27 of Set 7 | oistins
# Processing Record 28 of Set 7 | klyuchi
# Processing Record 29 of Set 7 | neyshabur
# Processing Record 30 of Set 7 | havelock
# Processing Record 31 of Set 7 | verkhoyansk
# Processing Record 32 of Set 7 | mao
# Processing Record 33 of Set 7 | mackay
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | haapiti
# Processing Record 36 of Set 7 | nantucket
# Processing Record 37 of Set 7 | mingguang
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | oktyabrskiy
# Processing Record 40 of Set 7 | kibala
# Processing Record 41 of Set 7 | sarangani
# Processing Record 42 of Set 7 | bengkulu
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | nemuro
# Processing Record 45 of Set 7 | northam
# Processing Record 46 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 7 | college
# Processing Record 48 of Set 7 | sola
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | vryburg
# Processing Record 1 of Set 8 | malanje
# Processing Record 2 of Set 8 | iqaluit
# Processing Record 3 of Set 8 | velikiy ustyug
# Processing Record 4 of Set 8 | boende
# Processing Record 5 of Set 8 | inhambane
# Processing Record 6 of Set 8 | xining
# Processing Record 7 of Set 8 | pokhara
# Processing Record 8 of Set 8 | sahuaripa
# Processing Record 9 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 8 | inegol
# Processing Record 11 of Set 8 | sitka
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | tasiilaq
# Processing Record 14 of Set 8 | chumikan
# Processing Record 15 of Set 8 | mlonggo
# Processing Record 16 of Set 8 | cuervos
# Processing Record 17 of Set 8 | balabac
# Processing Record 18 of Set 8 | qaqortoq
# Processing Record 19 of Set 8 | bocana de paiwas
# Processing Record 20 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | adre
# Processing Record 23 of Set 8 | kulachi
# Processing Record 24 of Set 8 | road town
# Processing Record 25 of Set 8 | ekhabi
# Processing Record 26 of Set 8 | vanimo
# Processing Record 27 of Set 8 | urumqi
# Processing Record 28 of Set 8 | ghorawal
# Processing Record 29 of Set 8 | bata
# Processing Record 30 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 8 | san rafael
# Processing Record 32 of Set 8 | menongue
# Processing Record 33 of Set 8 | santa cruz
# Processing Record 34 of Set 8 | abeche
# Processing Record 35 of Set 8 | mareeba
# Processing Record 36 of Set 8 | goderich
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | hofn
# Processing Record 42 of Set 8 | blyznyuky
# Processing Record 43 of Set 8 | itarema
# Processing Record 44 of Set 8 | kudahuvadhoo
# Processing Record 45 of Set 8 | erdenet
# Processing Record 46 of Set 8 | eureka
# Processing Record 47 of Set 8 | ossora
# Processing Record 48 of Set 8 | ilirska bistrica
# Processing Record 49 of Set 8 | mongu
# Processing Record 50 of Set 8 | lucapa
# Processing Record 1 of Set 9 | mariental
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | tura
# Processing Record 4 of Set 9 | yarmouth
# Processing Record 5 of Set 9 | bubaque
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | tautira
# Processing Record 8 of Set 9 | kattivakkam
# Processing Record 9 of Set 9 | guerrero negro
# Processing Record 10 of Set 9 | albion
# Processing Record 11 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 9 | keningau
# Processing Record 13 of Set 9 | norman wells
# Processing Record 14 of Set 9 | shingu
# Processing Record 15 of Set 9 | indramayu
# Processing Record 16 of Set 9 | shimoda
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | calolziocorte
# Processing Record 19 of Set 9 | ostrovnoy
# Processing Record 20 of Set 9 | tromso
# Processing Record 21 of Set 9 | bairiki
# Processing Record 22 of Set 9 | thabazimbi
# Processing Record 23 of Set 9 | longonjo
# Processing Record 24 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | valladolid
# Processing Record 26 of Set 9 | jalu
# Processing Record 27 of Set 9 | kavieng
# Processing Record 28 of Set 9 | ponta delgada
# Processing Record 29 of Set 9 | krasnyy luch
# Processing Record 30 of Set 9 | chapais
# Processing Record 31 of Set 9 | wittmund
# Processing Record 32 of Set 9 | hualmay
# Processing Record 33 of Set 9 | clyde river
# Processing Record 34 of Set 9 | pacifica
# Processing Record 35 of Set 9 | nevelsk
# Processing Record 36 of Set 9 | porto seguro
# Processing Record 37 of Set 9 | banjar
# Processing Record 38 of Set 9 | pinega
# Processing Record 39 of Set 9 | tinaquillo
# Processing Record 40 of Set 9 | diamantino
# Processing Record 41 of Set 9 | sabang
# Processing Record 42 of Set 9 | tara
# Processing Record 43 of Set 9 | boma
# Processing Record 44 of Set 9 | north bend
# Processing Record 45 of Set 9 | aksarka
# Processing Record 46 of Set 9 | half moon bay
# Processing Record 47 of Set 9 | upington
# Processing Record 48 of Set 9 | port hardy
# Processing Record 49 of Set 9 | tiksi
# Processing Record 50 of Set 9 | ancud
# Processing Record 1 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 10 | zverinogolovskoye
# Processing Record 3 of Set 10 | atambua
# Processing Record 4 of Set 10 | chinhoyi
# Processing Record 5 of Set 10 | cairo
# Processing Record 6 of Set 10 | san cristobal
# Processing Record 7 of Set 10 | brodokalmak
# Processing Record 8 of Set 10 | bojnurd
# Processing Record 9 of Set 10 | kloulklubed
# Processing Record 10 of Set 10 | darhan
# Processing Record 11 of Set 10 | santa comba
# Processing Record 12 of Set 10 | okhotsk
# Processing Record 13 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 10 | humaita
# Processing Record 15 of Set 10 | malchin
# Processing Record 16 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 10 | kalevala
# Processing Record 18 of Set 10 | sertania
# Processing Record 19 of Set 10 | shu
# Processing Record 20 of Set 10 | doha
# Processing Record 21 of Set 10 | dalnerechensk
# Processing Record 22 of Set 10 | cascais
# Processing Record 23 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 24 of Set 10 | namibe
# Processing Record 25 of Set 10 | porosozero
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | predivinsk
# Processing Record 28 of Set 10 | christchurch
# Processing Record 29 of Set 10 | warri
# Processing Record 30 of Set 10 | garowe
# Processing Record 31 of Set 10 | ginda
# Processing Record 32 of Set 10 | kotelnich
# Processing Record 33 of Set 10 | tual
# Processing Record 34 of Set 10 | waingapu
# Processing Record 35 of Set 10 | aykhal
# Processing Record 36 of Set 10 | matay
# Processing Record 37 of Set 10 | andilamena
# Processing Record 38 of Set 10 | mahebourg
# Processing Record 39 of Set 10 | deputatskiy
# Processing Record 40 of Set 10 | kavaratti
# Processing Record 41 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 10 | tshane
# Processing Record 43 of Set 10 | namatanai
# Processing Record 44 of Set 10 | comodoro rivadavia
# Processing Record 45 of Set 10 | arlit
# Processing Record 46 of Set 10 | soe
# Processing Record 47 of Set 10 | cairns
# Processing Record 48 of Set 10 | laurel
# Processing Record 49 of Set 10 | dzhebariki-khaya
# Processing Record 50 of Set 10 | kantunilkin
# Processing Record 1 of Set 11 | high rock
# Processing Record 2 of Set 11 | butler
# Processing Record 3 of Set 11 | zhezkazgan
# Processing Record 4 of Set 11 | sibi
# Processing Record 5 of Set 11 | bataipora
# Processing Record 6 of Set 11 | tecoanapa
# Processing Record 7 of Set 11 | pierre
# Processing Record 8 of Set 11 | ternate
# Processing Record 9 of Set 11 | gazanjyk
# Processing Record 10 of Set 11 | slave lake
# Processing Record 11 of Set 11 | kassala
# Processing Record 12 of Set 11 | katangli
# Processing Record 13 of Set 11 | pitimbu
# Processing Record 14 of Set 11 | eyl
# Processing Record 15 of Set 11 | husavik
# Processing Record 16 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 11 | csabrendek
# Processing Record 18 of Set 11 | mogadishu
# Processing Record 19 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 11 | giresun
# Processing Record 21 of Set 11 | ypsonas
# Processing Record 22 of Set 11 | minab
# Processing Record 23 of Set 11 | hongjiang
# Processing Record 24 of Set 11 | maceio
# Processing Record 25 of Set 11 | chkalovskoye
# Processing Record 26 of Set 11 | savalou
# Processing Record 27 of Set 11 | neftcala
# Processing Record 28 of Set 11 | boyolangu
# Processing Record 29 of Set 11 | ouadda
# Processing Record 30 of Set 11 | yumen
# Processing Record 31 of Set 11 | cherdyn
# Processing Record 32 of Set 11 | vitim
# Processing Record 33 of Set 11 | lompoc
# Processing Record 34 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 11 | gorgan
# Processing Record 36 of Set 11 | san quintin
# Processing Record 37 of Set 11 | west wendover
# Processing Record 38 of Set 11 | tumut
# Processing Record 39 of Set 11 | burnie
# Processing Record 40 of Set 11 | mizan teferi
# Processing Record 41 of Set 11 | zaplyusye
# City not found. Skipping...
# Processing Record 42 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 11 | trelew
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | mirebalais
# Processing Record 46 of Set 11 | bekovo
# Processing Record 47 of Set 11 | male
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | lingao
# Processing Record 50 of Set 11 | treinta y tres
# Processing Record 1 of Set 12 | camapua
# Processing Record 2 of Set 12 | toyooka
# Processing Record 3 of Set 12 | kargasok
# Processing Record 4 of Set 12 | kualakapuas
# Processing Record 5 of Set 12 | stolin
# Processing Record 6 of Set 12 | pinawa
# Processing Record 7 of Set 12 | padang
# Processing Record 8 of Set 12 | haines junction
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | paracatu
# Processing Record 11 of Set 12 | rincon
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | greymouth
# Processing Record 14 of Set 12 | port lincoln
# Processing Record 15 of Set 12 | mporokoso
# Processing Record 16 of Set 12 | merauke
# Processing Record 17 of Set 12 | vuktyl
# Processing Record 18 of Set 12 | santa cruz cabralia
# Processing Record 19 of Set 12 | poum
# Processing Record 20 of Set 12 | neuquen
# Processing Record 21 of Set 12 | bogande
# Processing Record 22 of Set 12 | mexico
# Processing Record 23 of Set 12 | tiarei
# Processing Record 24 of Set 12 | beira
# Processing Record 25 of Set 12 | axim
# Processing Record 26 of Set 12 | mercedes
# Processing Record 27 of Set 12 | prince rupert
# Processing Record 28 of Set 12 | rosa zarate
# Processing Record 29 of Set 12 | tavda
# Processing Record 30 of Set 12 | labuhan
# Processing Record 31 of Set 12 | poso
# Processing Record 32 of Set 12 | kochubey
# Processing Record 33 of Set 12 | sao joao da ponte
# Processing Record 34 of Set 12 | meshchovsk
# Processing Record 35 of Set 12 | barra do garcas
# Processing Record 36 of Set 12 | ukiah
# Processing Record 37 of Set 12 | bajil
# Processing Record 38 of Set 12 | port-gentil
# Processing Record 39 of Set 12 | gander
# Processing Record 40 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 12 | sandpoint
# Processing Record 42 of Set 12 | sorong
# Processing Record 43 of Set 12 | hegra
# Processing Record 44 of Set 12 | marienburg
# Processing Record 45 of Set 12 | vila franca do campo
# Processing Record 46 of Set 12 | kiruna
# Processing Record 47 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 12 | lodja
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | klaeng
# Processing Record 1 of Set 13 | santa maria
# Processing Record 2 of Set 13 | pringsewu
# Processing Record 3 of Set 13 | tongren
# Processing Record 4 of Set 13 | general roca
# Processing Record 5 of Set 13 | babu
# Processing Record 6 of Set 13 | novoseleznevo
# Processing Record 7 of Set 13 | bandar-e lengeh
# Processing Record 8 of Set 13 | tonj
# Processing Record 9 of Set 13 | sao felix do xingu
# Processing Record 10 of Set 13 | ilulissat
# Processing Record 11 of Set 13 | oksbol
# Processing Record 12 of Set 13 | sept-iles
# Processing Record 13 of Set 13 | howard springs
# Processing Record 14 of Set 13 | meulaboh
# Processing Record 15 of Set 13 | sao joao da barra
# Processing Record 16 of Set 13 | erzin
# Processing Record 17 of Set 13 | acari
# Processing Record 18 of Set 13 | zhanaozen
# Processing Record 19 of Set 13 | wamba
# Processing Record 20 of Set 13 | nhamunda
# Processing Record 21 of Set 13 | iquitos
# Processing Record 22 of Set 13 | laon
# Processing Record 23 of Set 13 | marsh harbour
# Processing Record 24 of Set 13 | honiara
# Processing Record 25 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 13 | margate
# Processing Record 27 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 28 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 13 | west bay
# Processing Record 32 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 13 | okha
# Processing Record 34 of Set 13 | muzhi
# Processing Record 35 of Set 13 | jucuaran
# Processing Record 36 of Set 13 | kadiri
# Processing Record 37 of Set 13 | singleton
# Processing Record 38 of Set 13 | fortuna
# Processing Record 39 of Set 13 | tarsus
# Processing Record 40 of Set 13 | two rivers
# Processing Record 41 of Set 13 | heinola
# Processing Record 42 of Set 13 | healesville
# Processing Record 43 of Set 13 | ahipara
# Processing Record 44 of Set 13 | klobuck
# Processing Record 45 of Set 13 | morondava
# Processing Record 46 of Set 13 | turukhansk
# Processing Record 47 of Set 13 | yamada
# Processing Record 48 of Set 13 | rocha
# Processing Record 49 of Set 13 | sompeta
# Processing Record 50 of Set 13 | torbay
# Processing Record 1 of Set 14 | palmeiras de goias
# Processing Record 2 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 14 | chake chake
# Processing Record 4 of Set 14 | kauhajoki
# Processing Record 5 of Set 14 | shenjiamen
# Processing Record 6 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 14 | ixtapa
# Processing Record 8 of Set 14 | bustonkala
# City not found. Skipping...
# Processing Record 9 of Set 14 | bello
# Processing Record 10 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 11 of Set 14 | saint-joseph
# Processing Record 12 of Set 14 | zyryanovsk
# Processing Record 13 of Set 14 | najran
# Processing Record 14 of Set 14 | sovetskoye
# Processing Record 15 of Set 14 | nouakchott
# Processing Record 16 of Set 14 | narodychi
# Processing Record 17 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 14 | goure
# Processing Record 19 of Set 14 | sioux lookout
# Processing Record 20 of Set 14 | manoel urbano
# Processing Record 21 of Set 14 | say
# Processing Record 22 of Set 14 | kesennuma
# City not found. Skipping...
# Processing Record 23 of Set 14 | itupiranga
# Processing Record 24 of Set 14 | martapura
# Processing Record 25 of Set 14 | xifeng
# Processing Record 26 of Set 14 | magrath
# Processing Record 27 of Set 14 | imeni zhelyabova
# Processing Record 28 of Set 14 | lenine
# Processing Record 29 of Set 14 | jhawarian
# Processing Record 30 of Set 14 | tessalit
# Processing Record 31 of Set 14 | marawi
# Processing Record 32 of Set 14 | jackson
# Processing Record 33 of Set 14 | voznesenye
# Processing Record 34 of Set 14 | grenfell
# Processing Record 35 of Set 14 | allanmyo
# City not found. Skipping...
# Processing Record 36 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 14 | oga
# Processing Record 38 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 14 | tilichiki
# Processing Record 40 of Set 14 | kortkeros
# Processing Record 41 of Set 14 | grindavik
# Processing Record 42 of Set 14 | kalyazin
# Processing Record 43 of Set 14 | encruzilhada
# Processing Record 44 of Set 14 | xai-xai
# Processing Record 45 of Set 14 | lithakia
# Processing Record 46 of Set 14 | riyadh
# Processing Record 47 of Set 14 | jardim
# Processing Record 48 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 14 | tongling
# Processing Record 50 of Set 14 | viedma
# Processing Record 1 of Set 15 | voi
# Processing Record 2 of Set 15 | iwanai
# Processing Record 3 of Set 15 | lahad datu
# Processing Record 4 of Set 15 | arroio grande
# Processing Record 5 of Set 15 | zainsk
# Processing Record 6 of Set 15 | coracao de jesus
# Processing Record 7 of Set 15 | zhigansk
# Processing Record 8 of Set 15 | suleja
# Processing Record 9 of Set 15 | bani
# Processing Record 10 of Set 15 | sao joao do piaui
# Processing Record 11 of Set 15 | ler
# Processing Record 12 of Set 15 | coahuayana
# Processing Record 13 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 15 | jalingo
# Processing Record 15 of Set 15 | nhulunbuy
# Processing Record 16 of Set 15 | angoche
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | neiafu
# Processing Record 19 of Set 15 | lepaterique
# Processing Record 20 of Set 15 | baherden
# Processing Record 21 of Set 15 | mateare
# Processing Record 22 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 15 | asfi
# Processing Record 24 of Set 15 | terrak
# Processing Record 25 of Set 15 | soyo
# Processing Record 26 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 15 | nelson bay
# Processing Record 28 of Set 15 | chimbote
# Processing Record 29 of Set 15 | gondar
# Processing Record 30 of Set 15 | quesnel
# Processing Record 31 of Set 15 | puerto armuelles
# Processing Record 32 of Set 15 | green river
# Processing Record 33 of Set 15 | kelso
# Processing Record 34 of Set 15 | teruel
# Processing Record 35 of Set 15 | lugovoy
# Processing Record 36 of Set 15 | kutum
# Processing Record 37 of Set 15 | salta
# Processing Record 38 of Set 15 | san julian
# Processing Record 39 of Set 15 | dong hoi
# Processing Record 40 of Set 15 | richards bay
# Processing Record 41 of Set 15 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 42 of Set 15 | linfen
# Processing Record 43 of Set 15 | kholtoson
# Processing Record 44 of Set 15 | sosnogorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lorengau      PG  -2.0226  147.2712     80.58        78         100
# 1          Mataura      NZ -46.1927  168.8643     45.48        80         100
# 2     Saint-Pierre      RE -21.3393   55.4781     66.90        77           0
# 3         Saldanha      ZA -33.0117   17.9442     53.65        79           0
# 4           Dikson      RU  73.5069   80.5464     35.49        96          92
# 5      Tuktoyaktuk      CA  69.4541 -133.0374     59.00        88          75
# 6     Punta Arenas      CL -53.1500  -70.9167     30.22        96          20
# 7           Mirnyy      RU  62.5353  113.9611     55.24        87         100
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     80.56        65           0
# 9   Saint-Philippe      RE -21.3585   55.7679     65.79        78          65
#
#    Wind Speed           Current Description
# 0        3.33                    light rain
# 1        7.52               overcast clouds
# 2       10.36                     clear sky
# 3        1.21                     clear sky
# 4       10.76               overcast clouds
# 5        3.44  thunderstorm with light rain
# 6        4.61                    few clouds
# 7        8.99               overcast clouds
# 8       13.80                     clear sky
# 9       10.65                 broken clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(path_or_buf= 'Weather_Database'+'WeatherPy_Database.csv', index_label="City_ID")
